# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('uscovid19.csv')

# %%
df.shape
# Out:
# (58, 18)

# %%
df.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %%
df
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-05-21 02:32:54  32.3182
# 1                     Alaska             US  2020-05-21 02:32:54  61.3707
# 2             American Samoa             US  2020-05-21 02:32:54 -14.2710
# 3                    Arizona             US  2020-05-21 02:32:54  33.7298
# 4                   Arkansas             US  2020-05-21 02:32:54  34.9697
# 5                 California             US  2020-05-21 02:32:54  36.1162
# 6                   Colorado             US  2020-05-21 02:32:54  39.0598
# 7                Connecticut             US  2020-05-21 02:32:54  41.5978
# 8                   Delaware             US  2020-05-21 02:32:54  39.3185
# 9           Diamond Princess             US  2020-05-21 02:32:54      NaN
# 10      District of Columbia             US  2020-05-21 02:32:54  38.8974
# 11                   Florida             US  2020-05-21 02:32:54  27.7663
# ...

# %%
df.drop('Country_Region',axis=1,inplace=True)
df.drop('Last_Update',axis=1,inplace=True)

# %%
df
# Out:
#               Province_State      Lat     Long_  Confirmed  Deaths  Recovered  \
# 0                    Alabama  32.3182  -86.9023      13052     522        NaN
# 1                     Alaska  61.3707 -152.4044        401      10      352.0
# 2             American Samoa -14.2710 -170.1320          0       0        NaN
# 3                    Arizona  33.7298 -111.4312      14906     747     3773.0
# 4                   Arkansas  34.9697  -92.3731       5003     107     3852.0
# 5                 California  36.1162 -119.6816      85997    3497        NaN
# 6                   Colorado  39.0598 -105.3111      22797    1299     3478.0
# 7                Connecticut  41.5978  -72.7554      39017    3529     6264.0
# 8                   Delaware  39.3185  -75.5071       8194     310     3965.0
# 9           Diamond Princess      NaN       NaN         49       0        NaN
# 10      District of Columbia  38.8974  -77.0268       7551     407     1059.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Province_State']=le.fit_transform(df['Province_State'].astype(str))

# %%
df
# Out:
#     Province_State      Lat     Long_  Confirmed  Deaths  Recovered    Active  \
# 0                0  32.3182  -86.9023      13052     522        NaN   12530.0
# 1                1  61.3707 -152.4044        401      10      352.0      39.0
# 2                2 -14.2710 -170.1320          0       0        NaN       0.0
# 3                3  33.7298 -111.4312      14906     747     3773.0   10386.0
# 4                4  34.9697  -92.3731       5003     107     3852.0    1044.0
# 5                5  36.1162 -119.6816      85997    3497        NaN   82500.0
# 6                6  39.0598 -105.3111      22797    1299     3478.0   18020.0
# 7                7  41.5978  -72.7554      39017    3529     6264.0   29224.0
# 8                8  39.3185  -75.5071       8194     310     3965.0    3919.0
# 9                9      NaN       NaN         49       0        NaN      49.0
# 10              10  38.8974  -77.0268       7551     407     1059.0    6085.0
# ...

# %%
df['ISO3']=le.fit_transform(df['ISO3'].astype(str))

# %%
df
# Out:
#     Province_State      Lat     Long_  Confirmed  Deaths  Recovered    Active  \
# 0                0  32.3182  -86.9023      13052     522        NaN   12530.0
# 1                1  61.3707 -152.4044        401      10      352.0      39.0
# 2                2 -14.2710 -170.1320          0       0        NaN       0.0
# 3                3  33.7298 -111.4312      14906     747     3773.0   10386.0
# 4                4  34.9697  -92.3731       5003     107     3852.0    1044.0
# 5                5  36.1162 -119.6816      85997    3497        NaN   82500.0
# 6                6  39.0598 -105.3111      22797    1299     3478.0   18020.0
# 7                7  41.5978  -72.7554      39017    3529     6264.0   29224.0
# 8                8  39.3185  -75.5071       8194     310     3965.0    3919.0
# 9                9      NaN       NaN         49       0        NaN      49.0
# 10              10  38.8974  -77.0268       7551     407     1059.0    6085.0
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#     Province_State      Lat     Long_  Confirmed  Deaths  Recovered    Active  \
# 3                3  33.7298 -111.4312      14906     747     3773.0   10386.0
# 4                4  34.9697  -92.3731       5003     107     3852.0    1044.0
# 6                6  39.0598 -105.3111      22797    1299     3478.0   18020.0
# 7                7  41.5978  -72.7554      39017    3529     6264.0   29224.0
# 15              15  21.0943 -157.4983        643      17      578.0      48.0
# 16              16  44.2405 -114.4788       2506      77     1668.0     761.0
# 20              20  38.5266  -96.7265       8507     202      473.0    7832.0
# 21              21  37.6681  -84.6701       8167     376     2826.0    4965.0
# 23              23  44.6939  -69.3819       1819      73     1100.0     646.0
# 24              24  39.0639  -76.8021      42323    2123     2993.0   37207.0
# 27              27  45.6945  -93.9002      17670     786    12227.0    4657.0
# ...

# %%
df.shape
# Out:
# (27, 16)

# %%
mid = df['Deaths']
df.drop(labels=['Deaths'], axis=1, inplace = True)
df.insert(15, 'Deaths', mid)
df
# Out:
#     Province_State      Lat     Long_  Confirmed  Recovered    Active  FIPS  \
# 3                3  33.7298 -111.4312      14906     3773.0   10386.0     4
# 4                4  34.9697  -92.3731       5003     3852.0    1044.0     5
# 6                6  39.0598 -105.3111      22797     3478.0   18020.0     8
# 7                7  41.5978  -72.7554      39017     6264.0   29224.0     9
# 15              15  21.0943 -157.4983        643      578.0      48.0    15
# 16              16  44.2405 -114.4788       2506     1668.0     761.0    16
# 20              20  38.5266  -96.7265       8507      473.0    7832.0    20
# 21              21  37.6681  -84.6701       8167     2826.0    4965.0    21
# 23              23  44.6939  -69.3819       1819     1100.0     646.0    23
# 24              24  39.0639  -76.8021      42323     2993.0   37207.0    24
# 27              27  45.6945  -93.9002      17670    12227.0    4657.0    27
# ...

# %%
df.describe()
# Out:
#        Province_State        Lat       Long_      Confirmed     Recovered  \
# count       27.000000  27.000000   27.000000      27.000000     27.000000
# mean        31.518519  39.579870  -95.279459   24137.925926   5846.629630
# std         16.378622   5.719976   19.562585   66961.033471  11641.005515
# min          3.000000  21.094300 -157.498300     478.000000    440.000000
# 25%         20.500000  35.656550 -106.775500    3834.500000   1288.500000
# 50%         33.000000  40.150000  -93.900200    8167.000000   3023.000000
# 75%         45.500000  44.254500  -79.557500   16288.000000   4987.000000
# max         57.000000  47.528900  -69.381900  354370.000000  61886.000000
#
#               Active       FIPS  Incident_Rate  People_Tested  \
# count      27.000000  27.000000      27.000000   2.700000e+01
# mean    16718.111111  31.333333     377.854090   1.736362e+05
# std     50332.706229  15.568706     405.143373   2.766633e+05
# ...

# %%
x=df.iloc[:,0:15]

# %%
x
# Out:
#     Province_State      Lat     Long_  Confirmed  Recovered    Active  FIPS  \
# 3                3  33.7298 -111.4312      14906     3773.0   10386.0     4
# 4                4  34.9697  -92.3731       5003     3852.0    1044.0     5
# 6                6  39.0598 -105.3111      22797     3478.0   18020.0     8
# 7                7  41.5978  -72.7554      39017     6264.0   29224.0     9
# 15              15  21.0943 -157.4983        643      578.0      48.0    15
# 16              16  44.2405 -114.4788       2506     1668.0     761.0    16
# 20              20  38.5266  -96.7265       8507      473.0    7832.0    20
# 21              21  37.6681  -84.6701       8167     2826.0    4965.0    21
# 23              23  44.6939  -69.3819       1819     1100.0     646.0    23
# 24              24  39.0639  -76.8021      42323     2993.0   37207.0    24
# 27              27  45.6945  -93.9002      17670    12227.0    4657.0    27
# ...

# %%
y=df.iloc[:,15].values

# %%
y
# Out:
# array([  747,   107,  1299,  3529,    17,    77,   202,   376,    73,
#         2123,   786,   570,    16,   190,   283, 28636,    49,   299,
#          144,   538,   407,    46,   305,    90,  1075,   481,    11])

# %%
y=y.reshape(-1,1)

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()

# %%
x = scale.fit_transform(x)
x
# Out:
# array([[0.00000000e+00, 4.77990966e-01, 5.22798253e-01, 4.07695003e-02,
#         5.42427497e-02, 3.92834671e-02, 0.00000000e+00, 9.00811540e-02,
#         9.85846633e-02, 2.26209968e-02, 4.92243060e-01, 0.00000000e+00,
#         0.00000000e+00, 1.24455967e-02, 2.46468522e-01],
#        [1.85185185e-02, 5.24895402e-01, 7.39081488e-01, 1.27863868e-02,
#         5.55284315e-02, 3.87376528e-03, 1.92307692e-02, 6.81293728e-02,
#         5.20633546e-02, 6.15626433e-03, 1.30603269e-01, 1.92307692e-02,
#         0.00000000e+00, 1.11890295e-01, 1.84032159e-01],
#        [5.55555556e-02, 6.79620649e-01, 5.92252974e-01, 6.30672635e-02,
#         4.94417863e-02, 6.82192051e-02, 7.69230769e-02, 1.97616573e-01,
#         7.59901170e-02, 5.09529111e-02, 5.78692712e-01, 7.69230768e-02,
#         0.00000000e+00, 1.42331324e-02, 4.96829048e-01],
#        [7.40740741e-02, 7.75631180e-01, 9.61715413e-01, 1.08900456e-01,
#         9.47824106e-02, 1.10686589e-01, 9.61538462e-02, 5.90711997e-01,
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
x_train.shape
# Out:
# (21, 15)

# %%
y_train.shape
# Out:
# (21, 1)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.intercept_
# Out:
# array([16.])

# %%
lm.score(x_train,y_train)
# Out:
# 1.0

# %%
pred=lm.predict(x_test)
print("Pridicted result price:",pred)
print("Actual price:",y_test)
# Out:
# Pridicted result price: [[  73.]
#  [ 190.]
#  [2123.]
#  [  46.]
#  [ 747.]
#  [ 570.]]
# Actual price: [[  73]
#  [ 190]
#  [2123]
#  [  46]
#  [ 747]
#  [ 570]]

# %%
print('Error')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean square error:',mean_squared_error(y_test,pred))
print('Root Mean square error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Error
# Mean absolute error: 3.747876083555942e-11
# Mean square error: 1.8840847908485165e-21
# Root Mean square error: 4.340604555644889e-11

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test,pred))
# Out:
# 1.0

# %%
from sklearn.externals import joblib
joblib.dump(lm,'project9_covid.pkl')
# Out:
# ['project9_covid.pkl']
